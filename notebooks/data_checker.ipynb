# %%
import pandas as pd
old_data = pd.read_csv("../data/listings_detailed.csv")

# %%
df = old_data.copy()
print(df['host_response_time'].isna().sum())
print((df['host_response_time'] == "N/A").sum())
# Out:
# 3793
# 0
